# %% [markdown]
# ### Created by Rohit Chaturvedi
#
# #### Topic Covered :- Seaborn
#
# ###### Date Created :- 24-07-2021
#
# ###### For more reference (Github) :- https://github.com/ROHIT-1112?tab=repositories

# %% [markdown]
# #### Content
#
#
# * Pyplot
# * Lineplot
# * Bar Plot
# * Cat Plot
# * Histograms
# * Density Plots
# * Pair Plot
# * Scatter Plot
# * Time Series Plotting
# * Box Plot
# * Heatmap
# * Multi-Plot Grids

# %% [markdown]
# ### Resources :-

# %% [markdown]
# * https://elitedatascience.com/python-seaborn-tutorial*
#
# * **https://www.datacamp.com/community/tutorials/seaborn-python-tutorial** :- Best Resource ( to Learn in Depth)
# * https://www.analyticsvidhya.com/blog/2021/02/a-beginners-guide-to-seaborn-the-simplest-way-to-learn/

# %% [markdown]
# #### What is Seaborn ?
#
# * Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# * Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots.
#
#
# **Official Documentation od Seaborn :-** https://seaborn.pydata.org/
# * https://towardsdatascience.com/seaborn-python-8563c3d0ad41#:~:text=Seaborn%20is%20a%20data%20visualization,exploration%20and%20understanding%20of%20data.&text=Visualizing%20univariate%20and%20bivariate%20distribution.

# %% [markdown]
# #### Importing Library of Seaborn.

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #### Line Plots :-
# * A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency of each value.
# **Line Plot is Used for Comparison .*

# %% [markdown]
# * Example :- Comparing Data Analyst Salaries with respect to their experiences.

# %%
experiences = [2,0,3,7,9,11,15]
salary = [20000,5000,35000,60000,100000,120000,200000,]

# %%
sns.lineplot(x = experiences,y = salary)
plt.title("Salaries of Data Analyst by their Experience")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Plotting Multiple Graphs in One Graph

# %% [markdown]
# * We are also adding Software Engineer's salary in our Graph.

# %%
experience = [1,3,4,5,7,8,10,12]

data_analyst_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

software_engineers_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000 ]

# %%
sns.lineplot(experience,data_analyst_salary, label = "Data Analyst")
sns.lineplot(experience,software_engineers_salary,label = "Software Engineers")
plt.title("Salary of Data Analyst and Software Engineers by Their Experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.show();
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# * Seaborn has several datasets inside of it. We will use flights dataset for a real world example. First we will load the data.

# %%
flights_data = sns.load_dataset("flights")
flights_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_pivot = flights_data.pivot("year",'month','passengers')
flight_pivot.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %% [markdown]
# * As an Example , Let's see flights in May Month.

# %%
sns.lineplot(data = flight_pivot['May'],color ='r')
plt.title("Flights in May")
plt.xlabel("Years")
plt.ylabel("Passengers")
plt.tight_layout()
plt.grid(True)
plt.show();

# %% [markdown]
# * We can also see each month by one by.

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data = flights_data,x ="year",y ="passengers",hue ="month")
plt.title("Number of Passengers by year on Month Basis")
plt.xlabel("Years")
plt.ylabel("Passengers")
plt.show();

# %% [markdown]
# ##### Bar Plot
# * A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x-axis and a numerical column for the y-axis, and we see that it creates a plot taking a mean per categorical column.
#
# * https://www.geeksforgeeks.org/seaborn-barplot-method-in-python/
#
# **Official Documentation of Barplot** :- https://seaborn.pydata.org/generated/seaborn.barplot.html
# * We will use **barplot()** function

# %%
x =["A","B","C","D"]
Y = [3,8,1,10]

# %%
sns.barplot(x =x,y=Y)
plt.grid(True)
plt.show()

# %% [markdown]
# * Let's plots salaries of data scientists by their gender. We will use hue argument for that.

# %%
experience = [1,2,3,4,5,6,7,8]

data_scientists_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

genders = ["Men","Men","Women","Men","Women","Women","Women","Men"]

# %%
sns.barplot(x=experience,y=data_scientists_salary,hue=genders)

plt.title("Salaries of data scientists by their gender")
plt.grid(True)
plt.show()

# %% [markdown]
# * We can make it horizontal. We will use orient argument for that.

# %%
sns.barplot(y=experience,x=data_scientists_salary,orient = 'v')

plt.title("Salaries of data scientists")
plt.show()

# %% [markdown]
# * We can combine bar and line plot.

# %%
sns.barplot(x=experience,y=data_scientists_salary)
sns.lineplot(x=experience,y=data_scientists_salary)

plt.title("Salaries of data scientists")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ##### CatPlot
#
# * Figure-level interface for drawing categorical plots onto a FacetGrid. This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.
#
# ***Official Documentation of the catplot :- *** https://seaborn.pydata.org/generated/seaborn.catplot.html
# * https://www.geeksforgeeks.org/python-seaborn-catplot/

# %% [markdown]
# * For a real world example, we will use tips dataset of seaborn. First we will load it.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="day", y="total_bill", data=tips)

plt.show()

# %%
sns.catplot(x="day", y="total_bill", data=tips,hue ='sex')
plt.grid()

plt.show()

# %% [markdown]
# * The jitter parameter controls the magnitude of jitter or disables it altogether.

# %%
sns.catplot(x="day", y="total_bill", data=tips,jitter=False)

plt.title("Total Bills by Day")
plt.grid()

plt.show()

# %%
sns.catplot(x="day", y="total_bill", data=tips,jitter=False,hue ='sex')
plt.grid()

plt.title("Total Bills by Day and sex")

plt.show()

# %% [markdown]
# ##### Histogram {Used for Distribution}¶
# * A histogram is a graph showing frequency distributions.
# * A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins.
# **Official Documentation (Histogram)** :-https://seaborn.pydata.org/generated/seaborn.histplot.html
# **Official Documentation (DistPlot)** :- https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
notes = [30,74,94,14,55,47,63,28,88,44,53,18,66,74,81,10,39]

# %%
sns.distplot(a = notes,color ="r")
plt.grid(color ="black")
plt.title("Histogram of Notes")
plt.show()
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * kde here means Kernal Density Estimation. (For Reference :- https://www.tutorialspoint.com/seaborn/seaborn_kernel_density_estimates.htm#:~:text=Kernel%20Density%20Estimation%20(KDE)%20is,the%20kernel%20density%20estimation%20plot.)
# * Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. It is used for non-parametric analysis. Setting the hist flag to False in distplot will yield the kernel density estimation plot.
# * Kernel Density Estimate, KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable.

# %%
sns.distplot(a = notes,color ='g',kde =False)
plt.grid(color = 'blue')
plt.title("Histogram of Notes")
plt.show();

# %% [markdown]
# * Here now we are going to work with real dataset.

# %%
data = pd.read_csv("L:/Datasets/Extracted Datasets/HR Dataset/HR Dataset.csv")

# %%
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
data['Salary'].value_counts().head()
# Out:
# 57815    2
# 63025    2
# 61242    2
# 50274    1
# 67251    1
# Name: Salary, dtype: int64

# %%
data["Salary"].mean()
# Out:
# 69020.6848874598

# %%
data["Salary"].std()
# Out:
# 25156.636929646647

# %%
data["Salary"].shape
# Out:
# (311,)

# %%
data["Salary"].min()
# Out:
# 45046

# %%
data["Salary"].max()
# Out:
# 250000

# %%
bins_sal = np.random.normal(69020,25156,311)

# %% [markdown]
# * We will work with Salary Column.

# %%
plt.style.use("classic")
bins = [40000,55000,70000,85000,100000,120000]
sns.distplot(data["Salary"],bins = bins,color ="blue",kde =False)
plt.title("Salaries of Workers")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * Now we'll create plots to understand differences between Performance Scores of Employees. In order to do that, first we will divide dataset into 4 datasets by performance score.

# %%
fully_meets1 = data[data["PerformanceScore"]=="Fully Meets"]
fully_meets1.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 6           Andreola, Colby  10194          0                0         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
# 6            1       4            3                       0   95660  ...
#
#        ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
fully_meets = data[data["PerformanceScore"]=="Fully Meets"]
exceeds = data[data["PerformanceScore"]=="Exceeds"]
needs_improvement = data[data["PerformanceScore"]=="Needs Improvement"]
pip = data[data["PerformanceScore"]=="PIP"]

# %%
plt.figure(figsize =(20,8))
sns.distplot(a= fully_meets["Salary"], label="Fully Meets", kde=False)
sns.distplot(a=exceeds["Salary"] , label="Exceeds",kde =False)
sns.distplot(a= needs_improvement["Salary"], label="Needs Improvement", kde=False)
sns.distplot(a=pip["Salary"], label="Pip", kde=False)

plt.title("Histogram of Performance Scores of Employees by their Performance Score")

plt.legend()

plt.show()

# %% [markdown]
# ##### Density Plots :-
# * kde Plot :-
#   * A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#   * We will use **sns.kdeplot** command for that.
#   **Official Documentation** :- https://seaborn.pydata.org/generated/seaborn.kdeplot.html#:~:text=kdeplot,-seaborn.&text=Plot%20univariate%20or%20bivariate%20distributions,dataset%2C%20analagous%20to%20a%20histogram.
#   **Best Resource (For In Depth) :- https://www.geeksforgeeks.org/kde-plot-visualization-with-pandas-and-seaborn/

# %%
notes = [30,74,94,14,55,47,63,28,88,44,53,18,66,74,81]

# %%
sns.kdeplot(data=notes, shade=True) # Setting shade=True colors the area below the curve

plt.title("Density Plot of Notes")
plt.xlabel("Value range of Notes")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# * We're not restricted to a single column when creating a KDE plot. We can create a two-dimensional (2D) KDE plot with the sns.jointplot command.

# %% [markdown]
# * What is JointPlot?
# * Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
#
# **Official Documentation of JointPlot**:- https://seaborn.pydata.org/generated/seaborn.jointplot.html
#
# **For Better Understanding**:- https://www.geeksforgeeks.org/python-seaborn-jointplot-method/

# %%
first_exam_notes = [30,74,94,14,55,47,63,28,88,44,53,18,66,74,81]
final_exam_notes = [96,77,19,29,56,29,33,49,83,37,84,73,16,48,79]

# %%
sns.jointplot(x=first_exam_notes,y=final_exam_notes,kind="kde") # Setting shade=True colors the area below the curve

plt.show()

# %%
sns.kdeplot(data=first_exam_notes,label="First Exam Notes", color ='g',shade=True)
sns.kdeplot(data=final_exam_notes,label="Final Exam Notes", color ='r',shade=True)

plt.title("Kernel Density Plot of Notes")
plt.grid(True)
plt.legend(loc ='upper left')
plt.show()

# %% [markdown]
# #### Pair Plot
# * Plot pairwise relationships in a dataset. By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column.
# **Official Documentation of Pair Plot** :- https://seaborn.pydata.org/generated/seaborn.pairplot.html
# **Reference for (In Depth Concept)** :- https://www.geeksforgeeks.org/python-seaborn-pairplot-method/
#
# * We will use **sns.pairplot()** function in order to plot.

# %% [markdown]
# * For a real world example, we will use iris Dataset of seaborn.

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

plt.show()

# %% [markdown]
# * If we want a smaller plot, we should use less variables. For example, if we only want sepal_width and sepal_length, than would create a 2x2 plot
# * We can use vars or x_vars and y_vars to select the variables to plot.

# %%
sns.pairplot(data=iris, vars=["sepal_width", "sepal_length"])

plt.show()

# %%
sns.pairplot(data=iris, x_vars=["sepal_width", "sepal_length","petal_width"],
                        y_vars=["sepal_width", "sepal_length"],hue='species')

plt.show()

# %% [markdown]
# * Assigning a hue variable adds a semantic mapping and changes the default marginal plot to a layered kernel density estimate (KDE).
#
# * What is **hue** ?
# * In seaborn, the hue parameter represents which column in the data frame, you want to use for color encoding.
# **For More Detail** :- https://intellipaat.com/community/56906/what-is-hue-in-seaborn#:~:text=In%20seaborn%2C%20the%20hue%20parameter,to%20use%20for%20color%20encoding.

# %%
sns.pairplot(iris,hue="species")

plt.show()

# %% [markdown]
# * If we set corner=True to plot only the lower triangle.

# %%
sns.pairplot(iris,corner=True)

plt.show()

# %% [markdown]
# * The plot_kws and diag_kws parameters accept dicts of keyword arguments to customize the off-diagonal and diagonal plots, respectively.

# %%
sns.pairplot(data=iris,
            plot_kws={"marker":"+","linewidth":1},
            diag_kws={"fill":False})

plt.show()

# %% [markdown]
# #### Scatter Plots
# * Scatterplot can be used with several semantic groupings which can help to understand well in a graph. They can plot two-dimensional graphics that can be enhanced by mapping up to three additional variables while using the semantics of hue, size, and style parameters.
# **Official Documentation od Scatter Plot**:- https://seaborn.pydata.org/generated/seaborn.scatterplot.html
# **Resource (Study in Depth)**:- https://www.geeksforgeeks.org/scatterplot-using-seaborn-in-python/
#
# * We use the **sns.scatterplot()** command.

# %%
experience = [1,2,3,4,5,6,7,8]

data_scientists_salary = [6500, 9280, 10050, 13200, 16672, 21000, 23965, 29793]

# %%
sns.scatterplot(x=experience,y=data_scientists_salary)

plt.title("Data Scientist's Salaries by their experience")
plt.grid(True)
plt.show()

# %% [markdown]
# * Here we will use real data and use Human Resource Data.

# %%
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
data.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8)) # or plt.tight_layout()
sns.scatterplot(x=data.Salary,y=data.EngagementSurvey,color="g",marker = "*",s =250)
plt.grid(True)
plt.title("Salaries of Employees by their Engagement Survey Score")
plt.show()

# %% [markdown]
# * To double-check the strength of this relationship, we might like to add a regression line, or the line that best fits the data. We do this by changing the command to **sns.regplot**.

# %% [markdown]
# ##### What is Regplot ?
# * This method is used to plot data and a linear regression model fit.
# * This method is used to plot data and a linear regression model fit. There are a number of mutually exclusive options for estimating the regression model.
# **Official Documentation of Regplot**:- https://seaborn.pydata.org/generated/seaborn.regplot.html
# **Reference (To study in Depth)** :- https://www.geeksforgeeks.org/python-seaborn-regplot-method/
#
# **Type of Regression Techniques** :- https://www.geeksforgeeks.org/types-of-regression-techniques/

# %%
plt.figure(figsize=(20,8))

sns.regplot(x=data.Salary,y=data.EngagementSurvey,color="b")
plt.grid(True)
plt.title("Salaries of Employees by their Engagement Survey Score")
plt.show()

# %% [markdown]
# * We can use scatter plots to display the relationships between three variables! One way of doing this is by color-coding the points.
#
# * For instance, to understand how gender affects the relationship between salaries and Engagement Survey Scores of employees, we can color-code the points by **'Sex'**, and plot the other two columns on the axes. We will use **hue** argument for that.

# %%
plt.figure(figsize=(15,8))

sns.scatterplot(x=data.Salary,y=data.EngagementSurvey,hue=data.Sex)

plt.xlabel("Salary")
plt.ylabel("Engagement Survey Score")

plt.title("Salaries of Employees by their Engagement Survey Score based on Gender")
plt.show()

# %% [markdown]
# * We can use the **sns.lmplot()** command to add two regression lines, corresponding to males and females.

# %%
plt.figure(figsize=(15,10))
sns.lmplot(x="Salary",y="EngagementSurvey",hue="Sex",data=data);

plt.xlabel("Salary")
plt.ylabel("Engagement Survey Score")

plt.title("Salaries of Employees by their Engagement Survey Score based on Gender")
plt.show()

# %% [markdown]
# * Usually, we use scatter plots to highlight the relationship between two continuous variables (like "salary" and "engagement survey score"). However, we can adapt the design of the scatter plot to feature a categorical variable (like "sex") on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the **sns.swarmplot()** command.

# %%
plt.figure(figsize=(5,5))

sns.swarmplot(x="Sex",y="Salary",data=data)

plt.xlabel("Gender")
plt.ylabel("Salary")

plt.title("Salaries of Employees by their Gender")
plt.show()
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data['Sex'].value_counts().head()
# Out:
# F     176
# M     135
# Name: Sex, dtype: int64

# %% [markdown]
# #### BoxPlot
# * Box Plot is the visual representation of the depicting groups of numerical data through their quartiles. Boxplot is also used for detect the outlier in data set. It captures the summary of the data efficiently with a simple box and whiskers and allows us to compare easily across groups. Boxplot summarizes a sample data using 25th, 50th and 75th percentiles. These percentiles are also known as the lower quartile, median and upper quartile.
#
# * A box plot consist of 5 things.
#
# * Minimum
# * First Quartile or 25%
# * Median (Second Quartile) or 50%
# * Third Quartile or 75%
# * Maximum
#
# *  box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# **Official Documentation of BoxPlot**:- https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# **For Better Reference (In Depth)** :- https://www.geeksforgeeks.org/box-plot-visualization-with-pandas-and-seaborn/
#
# * We will is use **sns.boxplot()** function for that.

# %%
notes = [44,55,15,95,82,51,37,76,7,84,29,48]

# %%
sns.boxplot(x = notes,color ='orange')

plt.title("Boxplot of Notes",color ='r')

plt.show()

# %% [markdown]
# * Seaborn gets data automatically as x stick. But if we specify it as y, it will be horizontal.

# %%
sns.boxplot(y=notes,color="r")

plt.title("Boxplot of Notes")
plt.ylabel("Notes")

plt.show()

# %% [markdown]
# * We will use real Dataset :- HR Dataset.

# %%
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
plt.figure(figsize=(15,10))

sns.boxplot( x=data["PerformanceScore"], y=data["Salary"],hue= 'Sex',data=data )

plt.title("Boxplot of Salaries")
plt.ylabel("Salary")
plt.grid(True)
plt.xlabel("Persormance Score")

plt.show()

# %% [markdown]
# * The size of the individual boxplots can be altered with the width parameter. The default width is 1, so anything less of that creates a smaller width for the boxes.

# %%
sns.boxplot( x=data["PerformanceScore"], y=data["Salary"],width=0.5)

plt.title("Boxplot of Salaries")
plt.ylabel("Salary")
plt.xlabel("Persormance Score")

plt.show()

# %% [markdown]
# * We can draw a boxplot with nested grouping by two categorical variables.

# %%
plt.figure(figsize=(13,8))

sns.boxplot(x="PerformanceScore", y="Salary",hue="Sex",data=data, palette="winter" )

plt.title("Boxplot of Salaries")
plt.ylabel("Salary")
plt.xlabel("Persormance Score")

plt.show()

# %% [markdown]
# * We can draw a boxplot for each numeric variable in a DataFrame.

# %%
plt.figure(figsize=(18,8))

sns.boxplot(x="DaysLateLast30",y="PerformanceScore",data=data, palette="Set2",orient="h")

plt.title("Boxplot of Late days and Performance Score")
plt.ylabel("Performance Score")
plt.xlabel("Late Days")

plt.show()

# %% [markdown]
# * We can use **swarmplot()** to show the datapoints on top of the boxes.

# %%
plt.figure(figsize=(13,5))

sns.boxplot(x="PerformanceScore", y="Salary",data=data, palette="Set2")
sns.swarmplot(x="PerformanceScore", y="Salary",data=data,color="red",hue ='Sex')

plt.title("Boxplot of Salaries")
plt.ylabel("Salary")
plt.xlabel("Persormance Score")

plt.show()
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Heatmap
# * We will use **sns.heatmap()** function in order to create heatmaps.
#
# * For a real world example, we will use **flights** dataset of Seaborn.

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights['passengers'].min()
# Out:
# 104

# %%
flights['passengers'].max()
# Out:
# 622

# %% [markdown]
# * Let's make a pivot table in order to make this dataset ready to plot heatmap. Otherwise heatmap will not work.

# %%
flights_piv= flights.pivot("month","year","passengers")

# %%
flights_piv
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights_piv.dtypes
# Out:
# year
# 1949    int64
# 1950    int64
# 1951    int64
# 1952    int64
# 1953    int64
# 1954    int64
# 1955    int64
# 1956    int64
# 1957    int64
# 1958    int64
# 1959    int64
# 1960    int64
# dtype: object

# %%
sns.heatmap(flights_piv)

plt.title("Heatmap of Flights")

plt.show()

# %% [markdown]
# * We can change the limits of colormap by using vmin and vmax arguments.

# %%
sns.heatmap(flights_piv, vmin=100,vmax=700,cmap ='cubehelix')

plt.title("Heatmap of Flights")

plt.show()

# %% [markdown]
# * We can plot a heatmap for data centered on 500 with a diverging colormap.

# %%
sns.heatmap(flights_piv, center=400)

plt.title("Heatmap of Flights")

plt.show()

# %% [markdown]
# * We can annotate each cell with the numeric value using integer formatting. We can use annot argument for that.

# %%
plt.figure(figsize=(15,12))

sns.heatmap(flights_piv, annot=True,fmt="d") #FORMAT =FMT

plt.title("Heatmap of Flights")

plt.show()

# %% [markdown]
# * We can change the colormap by using cmap argument.

# %%
sns.heatmap(flights_piv, cmap="YlGnBu")

plt.title("Heatmap of Flights")

plt.show()

# %% [markdown]
# * If we don't want a colorbar, we need to make cbar argument false.

# %%
sns.heatmap(flights_piv, cbar=False)

plt.title("Heatmap of Flights")

plt.show()
